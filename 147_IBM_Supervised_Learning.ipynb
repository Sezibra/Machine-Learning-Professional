# %% [markdown]
# ## SUPERVISED MACHINE LEARNING

# %% [markdown]
# * Regression: y is numeric (stock price, location, box office revenue, etc.)
# * Classification: y is categorical (face recognition, customer churn, which word comes next)

# %% [markdown]
# ML Framework (applies to Supervised ML Models):
#
# Yp = ⨍(𝝮,x)
#
# x: Input
#
# Yp: Output (values predicted by the model)
#
# ⨍(.): Prediction function that generated predictions x and 𝝮.

# %% [markdown]
# * we try to train the model to find the best 𝝮 given past experience.

# %% [markdown]
# J(Y,Yp): Loss
#
# - most ML models define a quantitative score for how "good" our predictions are.
# - the Loss function typically measures how close our predictions are to the true values.

# %% [markdown]
# **Update Rule:** using features x and outcome Y, choose parameters 𝝮 to minimize loss J. !!!!

# %%
import os
os.getcwd()
# Out:
# '/Users/cansezgin/Python-Output/LEARNING-PATH'

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Full paths
path1 = "/Users/cansezgin/Python-Output/SAMPLE_TRAINING_DATA/ml_1.png"
path2 = "/Users/cansezgin/Python-Output/SAMPLE_TRAINING_DATA/ml_2.png"

# Load images
img1 = mpimg.imread(path1)
img2 = mpimg.imread(path2)

# Display side by side
fig, axes = plt.subplots(1, 2, figsize=(15, 5))

axes[0].imshow(img1)
axes[0].axis('off')
axes[0].set_title("ml_1.png")

axes[1].imshow(img2)
axes[1].axis('off')
axes[1].set_title("ml_2.png")

plt.tight_layout()
plt.show()
